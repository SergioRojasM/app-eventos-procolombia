# %%
import snowflake.connector
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas, pd_writer

# %%
# https://rlyrwig-obb42592.snowflakecomputing.com/

con = snowflake.connector.connect(
    user='SLROJASM90',
    password='Leymaro.0990',
    account='rlyrwig-obb42592',
    warehouse="COMPUTE_WH",
    database="PROCOLOMBIA_TURISMO",
    schema="BODEGA_DWH"
)
# Create a cursor object.
cur = con.cursor()

# Execute a statement that will generate a result set.
sql = "SELECT * FROM BODEGA_DWH.FCT_EVENTOS"
cur.execute(sql)
df = cur.fetch_pandas_all()
con.close()    
df
# Out:
#     ID              NOMBRE_EVENTO FECHA_EVENTO HORA_EVENTO  \
# 0    1       Fiesta de cumpleaños   2024-03-16    19:00:00
# 1    2         Reunión de trabajo   2024-03-17    09:30:00
# 2    3          Concierto en vivo   2024-03-18    20:00:00
# 3    4  Conferencia de tecnología   2024-03-19    14:00:00
# 4    5            Visita al museo   2024-03-20    11:00:00
# 5    6    Entrenamiento de fútbol   2024-03-21    16:00:00
# 6    7        Cena de aniversario   2024-03-22    19:30:00
# 7    8    Lanzamiento de producto   2024-03-23    10:00:00
# 8    9            Curso de cocina   2024-03-24    18:00:00
# 9   10        Excursión al bosque   2024-03-25    08:00:00
# 10   1       Fiesta de cumpleaños   2024-03-16    19:00:00
# 11   2         Reunión de trabajo   2024-03-17    09:30:00
# 12   3          Concierto en vivo   2024-03-18    20:00:00
# 13   4  Conferencia de tecnología   2024-03-19    14:00:00
# 14   5            Visita al museo   2024-03-20    11:00:00
# ...

# %%
con = snowflake.connector.connect(
    user='SLROJASM90',
    password='Leymaro.0990',
    account='rlyrwig-obb42592',
    warehouse="COMPUTE_WH",
    database="procolombia_turismo",
    schema="bodega_dwh"
)
success, nchunks, nrows, _ = write_pandas(con, df,  table_name= 'FCT_EVENTOS')

# %%
con = snowflake.connector.connect(
    user='SLROJASM90',
    password='Leymaro.0990',
    account='rlyrwig-obb42592',
    warehouse="COMPUTE_WH",
    database="procolombia_turismo",
    schema="bodega_dwh"
)
df.to_sql('fct_eventos', con, index=False, method=pd_writer)
# Out:
# C:\Users\sergio.rojas.WOMCOL\AppData\Local\Temp\ipykernel_183612\1834118321.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql('fct_eventos', con, index=False, method=pd_writer)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\wom\1_VIU\TFM\app-eventos-procolombia\.venv\lib\site-packages\pandas\io\sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2671 try:
# -> 2672     cur.execute(sql, *args)
#    2673     return cur
#
# ...

# %%
query = "SELECT * FROM bodega_dwh.fct_eventos"
df = pd.read_sql(query, con)
# Out:
# C:\Users\sergio.rojas.WOMCOL\AppData\Local\Temp\ipykernel_183612\2066325219.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con)

# %%
df
# Out:
#     ID              NOMBRE_EVENTO FECHA_EVENTO HORA_EVENTO  \
# 0    1       Fiesta de cumpleaños   2024-03-16    19:00:00
# 1    2         Reunión de trabajo   2024-03-17    09:30:00
# 2    3          Concierto en vivo   2024-03-18    20:00:00
# 3    4  Conferencia de tecnología   2024-03-19    14:00:00
# 4    5            Visita al museo   2024-03-20    11:00:00
# 5    6    Entrenamiento de fútbol   2024-03-21    16:00:00
# 6    7        Cena de aniversario   2024-03-22    19:30:00
# 7    8    Lanzamiento de producto   2024-03-23    10:00:00
# 8    9            Curso de cocina   2024-03-24    18:00:00
# 9   10        Excursión al bosque   2024-03-25    08:00:00
# 10   1       Fiesta de cumpleaños   2024-03-16    19:00:00
# 11   2         Reunión de trabajo   2024-03-17    09:30:00
# 12   3          Concierto en vivo   2024-03-18    20:00:00
# 13   4  Conferencia de tecnología   2024-03-19    14:00:00
# 14   5            Visita al museo   2024-03-20    11:00:00
# ...

# %%
print(con.cursor().execute())
